# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
import tensorflow as tf
from tensorflow.keras import layers

# %%
data = pd.read_csv("data\star_classification.csv")
data.head()
# Out:
#          obj_ID       alpha      delta         u         g         r
# 0  1.237661e+18  135.689107  32.494632  23.87882  22.27530  20.39501  \
# 1  1.237665e+18  144.826101  31.274185  24.77759  22.83188  22.58444
# 2  1.237661e+18  142.188790  35.582444  25.26307  22.66389  20.60976
# 3  1.237663e+18  338.741038  -0.402828  22.13682  23.77656  21.61162
# 4  1.237680e+18  345.282593  21.183866  19.43718  17.58028  16.49747
#
#           i         z  run_ID  rerun_ID  cam_col  field_ID   spec_obj_ID
# 0  19.16573  18.79371    3606       301        2        79  6.543777e+18  \
# 1  21.16812  21.61427    4518       301        5       119  1.176014e+19
# 2  19.34857  18.94827    3606       301        2       120  5.152200e+18
# 3  20.50454  19.25010    4192       301        3       214  1.030107e+19
# 4  15.97711  15.54461    8102       301        3       137  6.891865e+18
#
#     class  redshift  plate    MJD  fiber_ID
# 0  GALAXY  0.634794   5812  56354       171
# ...

# %%
data.columns
# Out:
# Index(['obj_ID', 'alpha', 'delta', 'u', 'g', 'r', 'i', 'z', 'run_ID',
#        'rerun_ID', 'cam_col', 'field_ID', 'spec_obj_ID', 'class', 'redshift',
#        'plate', 'MJD', 'fiber_ID'],
#       dtype='object')

# %%
data.shape
# Out:
# (100000, 18)

# %%
data.describe()
# Out:
#              obj_ID          alpha          delta              u
# count  1.000000e+05  100000.000000  100000.000000  100000.000000  \
# mean   1.237665e+18     177.629117      24.135305      21.980468
# std    8.438560e+12      96.502241      19.644665      31.769291
# min    1.237646e+18       0.005528     -18.785328   -9999.000000
# 25%    1.237659e+18     127.518222       5.146771      20.352353
# 50%    1.237663e+18     180.900700      23.645922      22.179135
# 75%    1.237668e+18     233.895005      39.901550      23.687440
# max    1.237681e+18     359.999810      83.000519      32.781390
#
#                    g              r              i              z
# count  100000.000000  100000.000000  100000.000000  100000.000000  \
# mean       20.531387      19.645762      19.084854      18.668810
# std        31.750292       1.854760       1.757895      31.728152
# min     -9999.000000       9.822070       9.469903   -9999.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 18 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   obj_ID       100000 non-null  float64
#  1   alpha        100000 non-null  float64
#  2   delta        100000 non-null  float64
#  3   u            100000 non-null  float64
#  4   g            100000 non-null  float64
#  5   r            100000 non-null  float64
#  6   i            100000 non-null  float64
#  7   z            100000 non-null  float64
#  8   run_ID       100000 non-null  int64
#  9   rerun_ID     100000 non-null  int64
#  10  cam_col      100000 non-null  int64
#  11  field_ID     100000 non-null  int64
#  12  spec_obj_ID  100000 non-null  float64
#  13  class        100000 non-null  object
#  14  redshift     100000 non-null  float64
#  15  plate        100000 non-null  int64
#  16  MJD          100000 non-null  int64
#  17  fiber_ID     100000 non-null  int64
# ...

# %%
data.isnull().sum()
# Out:
# obj_ID         0
# alpha          0
# delta          0
# u              0
# g              0
# r              0
# i              0
# z              0
# run_ID         0
# rerun_ID       0
# cam_col        0
# field_ID       0
# spec_obj_ID    0
# class          0
# redshift       0
# plate          0
# MJD            0
# fiber_ID       0
# dtype: int64

# %% [markdown]
# Data Visualizations

# %%
class_breakdown = data["class"].value_counts()

plt.figure(figsize=(10,5))
plt.title("Breakdown of Stellar Objects")
plt.xlabel("Class")
plt.ylabel("Number of Objects")
sns.barplot(x=["Galaxies (" + str(class_breakdown.values[0]) + ")", "Stars (" + str(class_breakdown.values[1]) + ")", "Quasars (" + str(class_breakdown.values[2]) + ")"], y=class_breakdown.values)

plt.show()

# %%
data.hist(bins=10, figsize=(14, 14))
plt.show()

# %% [markdown]
# Using alpha and delta ascension and declination angles to plot map

# %%
from astropy.coordinates import SkyCoord
import astropy.units as unit

coords = SkyCoord(ra=data['alpha']*(180*unit.degree).radian, dec=data['delta']*(180*unit.degree).radian, frame='icrs')
fig = plt.figure(figsize=(15, 15))
axis = fig.add_subplot(111, projection="mollweide")
axis.scatter(coords.ra.wrap_at(180*unit.degree).radian, coords.dec.radian, s=1, marker='.', c=data['class'])
axis.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[56], line 4
#       1 from astropy.coordinates import SkyCoord
#       2 import astropy.units as unit
# ----> 4 coords = SkyCoord(ra=data['alpha']*(180*unit.degree).radian, dec=data['delta']*(180*unit.degree).radian, frame='icrs')
#       5 fig = plt.figure(figsize=(15, 15))
#       6 axis = fig.add_subplot(111, projection="mollweide")
#
# File c:\Users\brand\AppData\Local\Programs\Python\Python310\lib\site-packages\astropy\units\quantity.py:1100, in Quantity.__getattr__(self, attr)
#    1095 """
#    1096 Quantities are able to directly convert to other units that
#    1097 have the same physical type.
#    1098 """
#    1099 if not self._include_easy_conversion_members:
# -> 1100     raise AttributeError(
#    1101         f"'{self.__class__.__name__}' object has no '{attr}' member"
#    1102     )
# ...

# %%
from astropy.coordinates import SkyCoord  # High-level coordinates
from astropy.coordinates import ICRS, Galactic, FK4, FK5  # Low-level frames
from astropy.coordinates import Angle, Latitude, Longitude  # Angles
import astropy.units as unit

ra = Longitude(data['alpha'], unit.degree)
dec = Latitude(data['delta'], unit.degree)
coords = SkyCoord(ra=ra, dec=dec, frame='icrs')

fig = plt.figure(figsize=(15, 15))
axis = fig.add_subplot(111, projection="mollweide")
axis.scatter(coords.ra.wrap_at(180*unit.degree).radian, coords.dec.radian, s=1)
axis.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\brand\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\axes\_axes.py:4439, in Axes._parse_scatter_color_args(c, edgecolors, kwargs, xsize, get_next_color_func)
#    4438 try:  # Is 'c' acceptable as PathCollection facecolors?
# -> 4439     colors = mcolors.to_rgba_array(c)
#    4440 except (TypeError, ValueError) as err:
#
# File c:\Users\brand\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\colors.py:487, in to_rgba_array(c, alpha)
#     486 else:
# --> 487     rgba = np.array([to_rgba(cc) for cc in c])
#     489 if alpha is not None:
#
# File c:\Users\brand\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\colors.py:487, in <listcomp>(.0)
#     486 else:
# --> 487     rgba = np.array([to_rgba(cc) for cc in c])
#     489 if alpha is not None:
#
# ...
